# %% [markdown]
# # Data Loading, Storage,

# %%
import numpy as np
import pandas as pd
np.random.seed(12345)
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(10, 6))
np.set_printoptions(precision=4, suppress=True)

# %% [markdown]
# ## Reading and Writing Data in Text Format

# %%
# !cat examples/ex1.csv

# %%
df = pd.read_csv('examples/ex1.csv')
df

# %%
pd.read_table('examples/ex1.csv', sep=',')

# %%
# !cat examples/ex2.csv

# %%
pd.read_csv('examples/ex2.csv', header=None)
pd.read_csv('examples/ex2.csv', names=['a', 'b', 'c', 'd', 'message'])

# %%
names = ['a', 'b', 'c', 'd', 'message']
pd.read_csv('examples/ex2.csv', names=names, index_col='message')

# %%
# !cat examples/csv_mindex.csv
parsed = pd.read_csv('examples/csv_mindex.csv',
                     index_col=['key1', 'key2'])
parsed

# %%
list(open('examples/ex3.txt'))

# %%
result = pd.read_table('examples/ex3.txt', sep='\s+')
result

# %%
# !cat examples/ex4.csv
pd.read_csv('examples/ex4.csv', skiprows=[0, 2, 3])

# %%
# !cat examples/ex5.csv
result = pd.read_csv('examples/ex5.csv')
result
pd.isnull(result)

# %%
result = pd.read_csv('examples/ex5.csv', na_values=['NULL'])
result

# %%
sentinels = {'message': ['foo', 'NA'], 'something': ['two']}
pd.read_csv('examples/ex5.csv', na_values=sentinels)

# %% [markdown]
# ### Reading Text Files in Pieces

# %%
pd.options.display.max_rows = 10

# %%
result = pd.read_csv('examples/ex6.csv')
result

# %%
pd.read_csv('examples/ex6.csv', nrows=5)

# %%
chunker = pd.read_csv('examples/ex6.csv', chunksize=1000)
chunker

# %%
chunker = pd.read_csv('examples/ex6.csv', chunksize=1000)

tot = pd.Series([])
for piece in chunker:
    tot = tot.add(piece['key'].value_counts(), fill_value=0)

tot = tot.sort_values(ascending=False)

# %%
tot[:10]

# %% [markdown]
# ### Writing Data to Text Format

# %%
data = pd.read_csv('examples/ex5.csv')
data

# %%
data.to_csv('examples/out.csv')
# !cat examples/out.csv

# %%
import sys
data.to_csv(sys.stdout, sep='|')

# %%
data.to_csv(sys.stdout, na_rep='NULL')

# %%
data.to_csv(sys.stdout, index=False, header=False)

# %%
data.to_csv(sys.stdout, index=False, columns=['a', 'b', 'c'])

# %%
dates = pd.date_range('1/1/2000', periods=7)
ts = pd.Series(np.arange(7), index=dates)
ts.to_csv('examples/tseries.csv')
# !cat examples/tseries.csv

# %% [markdown]
# ### Working with Delimited Formats

# %%
# !type examples\ex7.csv
# Out:
# "a","b","c"
# "1","2","3"
# "1","2","3"

# %%
import csv
f = open('examples/ex7.csv')

reader = csv.reader(f)

# %%
type(reader)
# Out:
# _csv.reader

# %%
reader

# %%
for line in reader:
    print(line)
    print(type(line))
# Out:
# ['a', 'b', 'c']
# <class 'list'>
# ['1', '2', '3']
# <class 'list'>
# ['1', '2', '3']
# <class 'list'>

# %%
with open('examples/ex7.csv') as f:
    lines = list(csv.reader(f))

# %%
header, values = lines[0], lines[1:]

# %%
data_dict = {h: v for h, v in zip(header, zip(*values))}
data_dict

# %% [markdown]
# class my_dialect(csv.Dialect):
#     lineterminator = '\n'
#     delimiter = ';'
#     quotechar = '"'
#     quoting = csv.QUOTE_MINIMAL

# %% [markdown]
# reader = csv.reader(f, dialect=my_dialect)

# %% [markdown]
# reader = csv.reader(f, delimiter='|')

# %% [markdown]
# with open('mydata.csv', 'w') as f:
#     writer = csv.writer(f, dialect=my_dialect)
#     writer.writerow(('one', 'two', 'three'))
#     writer.writerow(('1', '2', '3'))
#     writer.writerow(('4', '5', '6'))
#     writer.writerow(('7', '8', '9'))

# %% [markdown]
# ### JSON Data

# %%
obj = """
{"name": "Wes",
 "places_lived": ["United States", "Spain", "Germany"],
 "pet": null,
 "siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},
              {"name": "Katie", "age": 38,
               "pets": ["Sixes", "Stache", "Cisco"]}]
}
"""

# %%
import json
result = json.loads(obj)
result

# %%
asjson = json.dumps(result)

# %%
siblings = pd.DataFrame(result['siblings'], columns=['name', 'age'])
siblings

# %%
# !cat examples/example.json

# %%
data = pd.read_json('examples/example.json')
data

# %%
print(data.to_json())
print(data.to_json(orient='records'))

# %% [markdown]
# ### XML and HTML: Web Scraping

# %% [markdown]
# conda install lxml
# pip install beautifulsoup4 html5lib

# %%
tables = pd.read_html('examples/fdic_failed_bank_list.html')
len(tables)
failures = tables[0]
failures.head()

# %%
close_timestamps = pd.to_datetime(failures['Closing Date'])
close_timestamps.dt.year.value_counts()

# %% [markdown]
# #### Parsing XML with lxml.objectify

# %% [markdown]
# <INDICATOR>
#   <INDICATOR_SEQ>373889</INDICATOR_SEQ>
#   <PARENT_SEQ></PARENT_SEQ>
#   <AGENCY_NAME>Metro-North Railroad</AGENCY_NAME>
#   <INDICATOR_NAME>Escalator Availability</INDICATOR_NAME>
#   <DESCRIPTION>Percent of the time that escalators are operational
#   systemwide. The availability rate is based on physical observations performed
#   the morning of regular business days only. This is a new indicator the agency
#   began reporting in 2009.</DESCRIPTION>
#   <PERIOD_YEAR>2011</PERIOD_YEAR>
#   <PERIOD_MONTH>12</PERIOD_MONTH>
#   <CATEGORY>Service Indicators</CATEGORY>
#   <FREQUENCY>M</FREQUENCY>
#   <DESIRED_CHANGE>U</DESIRED_CHANGE>
#   <INDICATOR_UNIT>%</INDICATOR_UNIT>
#   <DECIMAL_PLACES>1</DECIMAL_PLACES>
#   <YTD_TARGET>97.00</YTD_TARGET>
#   <YTD_ACTUAL></YTD_ACTUAL>
#   <MONTHLY_TARGET>97.00</MONTHLY_TARGET>
#   <MONTHLY_ACTUAL></MONTHLY_ACTUAL>
# </INDICATOR>

# %%
from lxml import objectify

path = 'datasets/mta_perf/Performance_MNR.xml'
parsed = objectify.parse(open(path))
root = parsed.getroot()

# %%
data = []

skip_fields = ['PARENT_SEQ', 'INDICATOR_SEQ',
               'DESIRED_CHANGE', 'DECIMAL_PLACES']

for elt in root.INDICATOR:
    el_data = {}
    for child in elt.getchildren():
        if child.tag in skip_fields:
            continue
        el_data[child.tag] = child.pyval
    data.append(el_data)

# %%
perf = pd.DataFrame(data)
perf.head()

# %%
from io import StringIO
tag = '<a href="http://www.google.com">Google</a>'
root = objectify.parse(StringIO(tag)).getroot()

# %%
root
root.get('href')
root.text

# %% [markdown]
# ## Binary Data Formats

# %%
frame = pd.read_csv('examples/ex1.csv')
frame
frame.to_pickle('examples/frame_pickle')

# %%
pd.read_pickle('examples/frame_pickle')

# %%
# !rm examples/frame_pickle

# %% [markdown]
# ### Using HDF5 Format

# %%
frame = pd.DataFrame({'a': np.random.randn(100)})
store = pd.HDFStore('mydata.h5')
store['obj1'] = frame
store['obj1_col'] = frame['a']
store

# %%
store['obj1']

# %%
store.put('obj2', frame, format='table')
store.select('obj2', where=['index >= 10 and index <= 15'])
store.close()

# %%
frame.to_hdf('mydata.h5', 'obj3', format='table')
pd.read_hdf('mydata.h5', 'obj3', where=['index < 5'])

# %%
os.remove('mydata.h5')

# %% [markdown]
# ### Reading Microsoft Excel Files

# %%
xlsx = pd.ExcelFile('examples/ex1.xlsx')

# %%
pd.read_excel(xlsx, 'Sheet1')

# %%
frame = pd.read_excel('examples/ex1.xlsx', 'Sheet1')
frame

# %%
writer = pd.ExcelWriter('examples/ex2.xlsx')
frame.to_excel(writer, 'Sheet1')
writer.save()

# %%
frame.to_excel('examples/ex2.xlsx')

# %%
# !rm examples/ex2.xlsx

# %% [markdown]
# ## Interacting with Web APIs

# %%
import requests
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data = resp.json()
data[0]['title']
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42850',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42850/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42850/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42850/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/42850',
#   'id': 957953114,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NzAxMzAwMzM0',
#   'number': 42850,
#   'title': 'Backport PR #42787: BUG: 1D slices over extension types turn into N-dimensional slices over ExtensionArrays',
#   'user': {'login': 'simonjayhawkins',
#    'id': 13159005,
#    'node_id': 'MDQ6VXNlcjEzMTU5MDA1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13159005?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/simonjayhawkins',
#    'html_url': 'https://github.com/simonjayhawkins',
#    'followers_url': 'https://api.github.com/users/simonjayhawkins/followers',
#    'following_url': 'https://api.github.com/users/simonjayhawkins/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/simonjayhawkins/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/simonjayhawkins/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/simonjayhawkins/subscriptions',
#    'organizations_url': 'https://api.github.com/users/simonjayhawkins/orgs',
#    'repos_url': 'https://api.github.com/users/simonjayhawkins/repos',
#    'events_url': 'https://api.github.com/users/simonjayhawkins/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/simonjayhawkins/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 849023693,
#     'node_id': 'MDU6TGFiZWw4NDkwMjM2OTM=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/ExtensionArray',
#     'name': 'ExtensionArray',
#     'color': '6138b5',
#     'default': False,
#     'description': 'Extending pandas with custom dtypes or arrays.'},
#    {'id': 2822098,
#     'node_id': 'MDU6TGFiZWwyODIyMDk4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Indexing',
#     'name': 'Indexing',
#     'color': '0b02e1',
#     'default': False,
#     'description': 'Related to indexing on series/frames, not to indexes themselves'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/88',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/88',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/88/labels',
#    'id': 6998423,
#    'node_id': 'MI_kwDOAA0YD84AasmX',
#    'number': 88,
#    'title': '1.3.2',
#    'description': 'on-merge: backport to 1.3.x',
#    'creator': {'login': 'simonjayhawkins',
#     'id': 13159005,
#     'node_id': 'MDQ6VXNlcjEzMTU5MDA1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/13159005?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/simonjayhawkins',
#     'html_url': 'https://github.com/simonjayhawkins',
#     'followers_url': 'https://api.github.com/users/simonjayhawkins/followers',
#     'following_url': 'https://api.github.com/users/simonjayhawkins/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/simonjayhawkins/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/simonjayhawkins/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/simonjayhawkins/subscriptions',
#     'organizations_url': 'https://api.github.com/users/simonjayhawkins/orgs',
#     'repos_url': 'https://api.github.com/users/simonjayhawkins/repos',
#     'events_url': 'https://api.github.com/users/simonjayhawkins/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/simonjayhawkins/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 34,
#    'closed_issues': 33,
#    'state': 'open',
#    'created_at': '2021-07-23T08:57:52Z',
#    'updated_at': '2021-08-02T09:34:27Z',
#    'due_on': '2021-08-15T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2021-08-02T09:34:26Z',
#   'updated_at': '2021-08-02T09:34:27Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/42850',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/42850',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/42850.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/42850.patch'},
#   'body': 'Backport PR #42787',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42849',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42849/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42849/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42849/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/42849',
#   'id': 957884537,
#   'node_id': 'MDU6SXNzdWU5NTc4ODQ1Mzc=',
#   'number': 42849,
#   'title': "BUG: GroupBy's quantile incompatible with pd.NA",
#   'user': {'login': 'JP-Ellis',
#    'id': 3196162,
#    'node_id': 'MDQ6VXNlcjMxOTYxNjI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3196162?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JP-Ellis',
#    'html_url': 'https://github.com/JP-Ellis',
#    'followers_url': 'https://api.github.com/users/JP-Ellis/followers',
#    'following_url': 'https://api.github.com/users/JP-Ellis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/JP-Ellis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/JP-Ellis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/JP-Ellis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/JP-Ellis/orgs',
#    'repos_url': 'https://api.github.com/users/JP-Ellis/repos',
#    'events_url': 'https://api.github.com/users/JP-Ellis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/JP-Ellis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-08-02T08:13:53Z',
#   'updated_at': '2021-08-02T08:13:53Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [ ] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\nFirstly, here\'s a working example using the default dtypes:\r\n\r\n```python\r\ndf = pd.DataFrame({\r\n    "x": [1, 1],\r\n    "y": [0.2, np.nan]\r\n})\r\nprint(f"dtypes:\\n{df.dtypes}")\r\ndisplay(df.groupby("x")["y"].quantile(0.5))\r\n```\r\n<details>\r\n\r\n```text\r\ndtypes:\r\nx      int64\r\ny    float64\r\ndtype: object\r\nx\r\n1    0.2\r\nName: y, dtype: float64\r\n```\r\n\r\n</details>\r\n\r\nTo contrast, if I use the Pandas dtypes, the codef ails\r\n\r\n```python\r\ndf = pd.DataFrame({\r\n    "x": [1, 1],\r\n    "y": [0.2, np.nan]\r\n}).astype({"x": pd.Int64Dtype(), "y": pd.Float64Dtype()})\r\nprint(f"dtypes:\\n{df.dtypes}")\r\ndisplay(df.groupby("x")["y"].quantile(0.5))\r\n```\r\n<details>\r\n\r\n```text\r\ndtypes:\r\nx      Int64\r\ny    Float64\r\ndtype: object\r\n\r\nTypeError: float() argument must be a string or a number, not \'NAType\'\r\n\r\n---------------------------------------------------------------------------\r\nTypeError                                 Traceback (most recent call last)\r\n/tmp/josh/ipykernel_67869/1525766791.py in <module>\r\n      4 }).astype({"x": pd.Int64Dtype(), "y": pd.Float64Dtype()})\r\n      5 print(f"dtypes:\\n{df.dtypes}")\r\n----> 6 display(df.groupby("x")["y"].quantile(0.5))\r\n\r\n.../python3.9/site-packages/pandas/core/groupby/groupby.py in quantile(self, q, interpolation)\r\n   2450 \r\n   2451         if is_scalar(q):\r\n-> 2452             return self._get_cythonized_result(\r\n   2453                 "group_quantile",\r\n   2454                 aggregate=True,\r\n\r\n.../python3.9/site-packages/pandas/core/groupby/groupby.py in _get_cythonized_result(self, how, cython_dtype, aggregate, numeric_only, needs_counts, needs_values, needs_2d, needs_nullable, min_count, needs_mask, needs_ngroups, result_is_index, pre_processing, post_processing, **kwargs)\r\n   2899                         )\r\n   2900                         continue\r\n-> 2901                 vals = vals.astype(cython_dtype, copy=False)\r\n   2902                 if needs_2d:\r\n   2903                     vals = vals.reshape((-1, 1))\r\n\r\nTypeError: float() argument must be a string or a number, not \'NAType\'\r\n```\r\n\r\n</details>\r\n\r\nWhat is odd is that the quantile function works fine with if we avoid using groupby:\r\n\r\n```python\r\ndf["y"].quantile(0.5)\r\n```\r\n\r\n<details>\r\n\r\n```text\r\n0.2\r\n```\r\n\r\n</details>\r\n\r\n#### Problem description\r\n\r\nI would have expected that change from the default `float64` type to `pd.Float64Dtype` should produce the same results with the `NAN` values being treated in the same way.\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\n------------------\r\ncommit           : c7f7443c1bad8262358114d5e88cd9c8a308e8aa\r\npython           : 3.9.6.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.13.6-zen1-1-zen\r\nVersion          : #1 ZEN SMP PREEMPT Thu, 29 Jul 2021 00:21:08 +0000\r\nmachine          : x86_64\r\nprocessor        : \r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_AU.UTF-8\r\nLOCALE           : en_AU.UTF-8\r\n\r\npandas           : 1.3.1\r\nnumpy            : 1.21.1\r\npytz             : 2021.1\r\ndateutil         : 2.8.2\r\npip              : 21.1.3\r\nsetuptools       : 57.1.0\r\nCython           : None\r\npytest           : 6.2.4\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.0.1\r\nIPython          : 7.26.0\r\npandas_datareader: None\r\nbs4              : None\r\nbot ...
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42848',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42848/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42848/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42848/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/42848',
#   'id': 957826421,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NzAxMTkwMjk2',
#   'number': 42848,
#   'title': '⬆️ UPGRADE: Autoupdate pre-commit config',
#   'user': {'login': 'github-actions[bot]',
#    'id': 41898282,
#    'node_id': 'MDM6Qm90NDE4OTgyODI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/in/15368?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions%5Bbot%5D',
#    'html_url': 'https://github.com/apps/github-actions',
#    'followers_url': 'https://api.github.com/users/github-actions%5Bbot%5D/followers',
#    'following_url': 'https://api.github.com/users/github-actions%5Bbot%5D/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/github-actions%5Bbot%5D/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/github-actions%5Bbot%5D/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/github-actions%5Bbot%5D/subscriptions',
#    'organizations_url': 'https://api.github.com/users/github-actions%5Bbot%5D/orgs',
#    'repos_url': 'https://api.github.com/users/github-actions%5Bbot%5D/repos',
#    'events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/received_events',
#    'type': 'Bot',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-08-02T07:11:17Z',
#   'updated_at': '2021-08-02T07:11:17Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/42848',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/42848',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/42848.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/42848.patch'},
#   'body': "<!-- START pr-commits -->\n<!-- END pr-commits -->\n\n## Base PullRequest\n\ndefault branch (https://github.com/pandas-dev/pandas/tree/master)\n\n## Command results\n<details>\n<summary>Details: </summary>\n\n<details>\n<summary><em>add path</em></summary>\n\n```Shell\n/home/runner/work/_actions/technote-space/create-pr-action/v2/node_modules/npm-check-updates/bin\n```\n\n\n\n</details>\n<details>\n<summary><em>pip install pre-commit</em></summary>\n\n```Shell\nCollecting pre-commit\n  Downloading pre_commit-2.13.0-py2.py3-none-any.whl (190 kB)\nCollecting cfgv>=2.0.0\n  Downloading cfgv-3.3.0-py2.py3-none-any.whl (7.3 kB)\nCollecting nodeenv>=0.11.1\n  Using cached nodeenv-1.6.0-py2.py3-none-any.whl (21 kB)\nCollecting toml\n  Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)\nCollecting identify>=1.0.0\n  Downloading identify-2.2.11-py2.py3-none-any.whl (98 kB)\nCollecting pyyaml>=5.1\n  Using cached PyYAML-5.4.1-cp39-cp39-manylinux1_x86_64.whl (630 kB)\nCollecting virtualenv>=20.0.8\n  Downloading virtualenv-20.7.0-py2.py3-none-any.whl (5.3 MB)\nCollecting filelock<4,>=3.0.0\n  Using cached filelock-3.0.12-py3-none-any.whl (7.6 kB)\nCollecting distlib<1,>=0.3.1\n  Downloading distlib-0.3.2-py2.py3-none-any.whl (338 kB)\nCollecting backports.entry-points-selectable>=1.0.4\n  Downloading backports.entry_points_selectable-1.1.0-py2.py3-none-any.whl (6.2 kB)\nCollecting platformdirs<3,>=2\n  Downloading platformdirs-2.2.0-py3-none-any.whl (13 kB)\nCollecting six<2,>=1.9.0\n  Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)\nInstalling collected packages: six, platformdirs, filelock, distlib, backports.entry-points-selectable, virtualenv, toml, pyyaml, nodeenv, identify, cfgv, pre-commit\nSuccessfully installed backports.entry-points-selectable-1.1.0 cfgv-3.3.0 distlib-0.3.2 filelock-3.0.12 identify-2.2.11 nodeenv-1.6.0 platformdirs-2.2.0 pre-commit-2.13.0 pyyaml-5.4.1 six-1.16.0 toml-0.10.2 virtualenv-20.7.0\n```\n\n### stderr:\n\n```Shell\nWARNING: You are using pip version 21.2.1; however, version 21.2.2 is available.\nYou should consider upgrading via the '/opt/hostedtoolcache/Python/3.9.6/x64/bin/python -m pip install --upgrade pip' command.\n```\n\n</details>\n<details>\n<summary><em>pre-commit autoupdate || (exit 0);</em></summary>\n\n```Shell\nUpdating https://github.com/MarcoGorelli/absolufy-imports ... already up to date.\nUpdating https://github.com/python/black ... [INFO] Initializing environment for https://github.com/python/black.\nalready up to date.\nUpdating https://github.com/codespell-project/codespell ... [INFO] Initializing environment for https://github.com/codespell-project/codespell.\nalready up to date.\nUpdating https://github.com/pre-commit/pre-commit-hooks ... already up to date.\nUpdating https://github.com/cpplint/cpplint ... [INFO] Initializing environment for https://github.com/cpplint/cpplint.\nalready up to date.\nUpdating https://gitlab.com/pycqa/flake8 ... already up to date.\nUpdating https://github.com/PyCQA/isort ... [INFO] Initializing environment for https://github.com/PyCQA/isort.\nupdating 5.9.2 -> 5.9.3.\nUpdating https://github.com/asottile/pyupgrade ... [INFO] Initializing environment for https://github.com/asottile/pyupgrade.\nupdating v2.23.0 -> v2.23.1.\nUpdating https://github.com/pre-commit/pygrep-hooks ... [INFO] Initializing environment for https://github.com/pre-commit/pygrep-hooks.\nalready up to date.\nUpdating https://github.com/asottile/yesqa ... already up to date.\n```\n\n\n\n</details>\n<details>\n<summary><em>pre-commit run -a || (exit 0);</em></summary>\n\n```Shell\n[INFO] Installing environment for https://github.com/MarcoGorelli/absolufy-imports.\n[INFO] Once installed this environment will be reused.\n[INFO] This may take a few minutes...\n[INFO] Installing environment for https://github.com/python/black.\n[INFO] Once installed this environment will be reused.\n[INFO] This may take a few minutes...\n[INFO] Installing environment for https://gith ...
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42845',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42845/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42845/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42845/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/42845',
#   'id': 957613057,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NzAxMDA2MzY4',
#   'number': 42845,
#   'title': 'ENH: Allow bar and barh plots to use index values for x position.',
#   'user': {'login': 'killerrex',
#    'id': 1187546,
#    'node_id': 'MDQ6VXNlcjExODc1NDY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1187546?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/killerrex',
#    'html_url': 'https://github.com/killerrex',
#    'followers_url': 'https://api.github.com/users/killerrex/followers',
#    'following_url': 'https://api.github.com/users/killerrex/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/killerrex/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/killerrex/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/killerrex/subscriptions',
#    'organizations_url': 'https://api.github.com/users/killerrex/orgs',
#    'repos_url': 'https://api.github.com/users/killerrex/repos',
#    'events_url': 'https://api.github.com/users/killerrex/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/killerrex/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-08-01T23:25:11Z',
#   'updated_at': '2021-08-02T07:14:17Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/42845',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/42845',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/42845.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/42845.patch'},
#   'body': '_Note_: This is my first attempt to contribute code to pandas, so any correction is more than welcome.\r\n\r\n\r\nThis proposal adds a new parameter to the bar and barh plots, `x_mode`, with the values:\r\n- sequential: The index values are added sequentially (`x=1, 2, 3...`) and only the tick label shows the value.\r\n- numerical: The X axis positions will be related to the real index values.\r\n- categorical: The X axis ticks includes all the possible categories, even if are not all used in the index.\r\n\r\nWith these modes it is possible to create richer bar plots, useful to compare results from different samples.\r\n\r\n## Details\r\n\r\nWith the current bar and barh plots is difficult to create a graph where the categorical axis (x for bar) follows the real values\r\nof the input data.\r\nFor example, if we have 10 machines that are not always active and we are collecting the RAM and CPU usage we can have\r\na data set like:\r\n```python\r\ndata = pd.DataFrame({\r\n    \'machine\': [1, 6, 4, 2, 10],\r\n    \'cpu\': [0.9, 0.8, 0.8, 0.9, 0.7],\r\n    \'ram\': [0.6, 0.7, 0.2, 0.9, 1.0]\r\n})\r\n\r\ndata.plot.bar(x=\'machine\', rot=0)\r\n```\r\n![image](https://user-images.githubusercontent.com/1187546/127787243-6bbcb568-a51f-48dd-8181-88ad5ed379fb.png)\r\n\r\nThis can be misleading and difficult to compare with data from other sample:\r\n\r\n```python\r\nother = pd.DataFrame({\r\n    \'machine\': [2, 5, 4, 8, 10],\r\n    \'cpu\': [0.7, 0.3, 0.8, 0.7, 0.8],\r\n    \'ram\': [0.5, 0.9, 0.6, 0.6, 0.8]\r\n})\r\n\r\nfig, axes = plt.subplots(2, 1)\r\ndata.plot.bar(x=\'machine\', ax=axes[0], ylabel=\'day 1\', rot=0)\r\nother.plot.bar(x=\'machine\', ax=axes[1], ylabel=\'day 2\', rot=0)\r\nfig.suptitle(\'Difficult to correlate plots\')\r\n```\r\n![image](https://user-images.githubusercontent.com/1187546/127787490-637e1504-4733-46b9-8537-ab51998017ec.png)\r\n\r\nThis proposal introduces the possibility to interpret the x values according to the numerical value, solving this issue:\r\n\r\n```python\r\nfig, axes = plt.subplots(2, 1, sharex=\'col\')\r\ndata.plot.bar(x=\'machine\', ax=axes[0], ylabel=\'day 1\', rot=0, x_mode="numerical")\r\nother.plot.bar(x=\'machine\', ax=axes[1], ylabel=\'day 2\', rot=0, x_mode="numerical")\r\naxes[1].set_xlim(0.5, 10.5)\r\nfig.suptitle(\'Aligned plot\')\r\n```\r\n\r\n![image](https://user-images.githubusercontent.com/1187546/127787686-ed3a3bcc-76c7-4039-8d66-56b953aaf862.png)\r\n\r\nWhen the X axis is a categorical data it is possible to also include all the missing labels in the X-axis,\r\nso it is easier to compare graphs generated in different moments.\r\n\r\n```python\r\nmachines = [\'OP1\', \'OP2\', \'OP3\', \'OP4\', \'OP5\', \'SP1\', \'SP2\', \'SP3\', \'SP4\', \'SP5\']\r\nday_1 = pd.DataFrame({\'machine\': [\'OP1\', \'SP1\', \'OP4\', \'OP2\', \'SP5\'], \'cpu\': [0.9, 0.8, 0.8, 0.9, 0.7], \'ram\': [0.6, 0.7, 0.2, 0.9, 1.0]})\r\nday_1[\'machine\'] = pd.Categorical(day_1[\'machine\'], machines)\r\nday_2 = pd.DataFrame({\r\n    \'machine\': [\'OP2\', \'OP5\', \'OP4\', \'SP3\', \'SP4\'],\r\n    \'cpu\': [0.7, 0.3, 0.8, 0.7, 0.8],\r\n    \'ram\': [0.5, 0.9, 0.6, 0.6, 0.8]\r\n})\r\n\r\nday_2[\'machine\'] = pd.Categorical(day_2[\'machine\'], machines)\r\nfig, axes = plt.subplots(2, 1, sharex=\'col\')\r\nday_1.plot.bar(x=\'machine\', ax=axes[0], ylabel=\'day 1\', rot=0, x_mode="categorical")\r\nday_2.plot.bar(x=\'machine\', ax=axes[1], ylabel=\'day 2\', rot=0, x_mode="categorical")\r\nfig.suptitle(\'Plot with Categories\')\r\n```\r\n![image](https://user-images.githubusercontent.com/1187546/127787905-298e2935-a49b-4282-8c9f-1b55fbd667bd.png)\r\n\r\n\r\n## Other changes\r\n\r\nI also factorized the documentation of bar and barh so they share the same examples. In the current version of the docs there are subtle differences between the bar and barh pages, I tried to unify them.\r\n\r\n## Open Points\r\n\r\n- Not convinced at all with the name of the flag and the values, for sure someone can find  ...
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42844',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42844/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42844/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42844/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/42844',
#   'id': 957576754,
#   'node_id': 'MDU6SXNzdWU5NTc1NzY3NTQ=',
#   'number': 42844,
#   'title': 'BUG: DatetimeIndex has become unhashable in 1.3.1?',
#   'user': {'login': 'yohplala',
#    'id': 13206058,
#    'node_id': 'MDQ6VXNlcjEzMjA2MDU4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13206058?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yohplala',
#    'html_url': 'https://github.com/yohplala',
#    'followers_url': 'https://api.github.com/users/yohplala/followers',
#    'following_url': 'https://api.github.com/users/yohplala/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/yohplala/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/yohplala/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/yohplala/subscriptions',
#    'organizations_url': 'https://api.github.com/users/yohplala/orgs',
#    'repos_url': 'https://api.github.com/users/yohplala/repos',
#    'events_url': 'https://api.github.com/users/yohplala/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/yohplala/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-08-01T20:15:54Z',
#   'updated_at': '2021-08-01T20:15:54Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [ ] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\nHi,\r\nFollowing code below was working with pandas 1.2.5.\r\nIt raises now an error with pandas 1.3.1.\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\nimport pandas as pd\r\nimport random\r\n\r\n# Right data\r\nts_open = pd.DatetimeIndex([\r\n                           pd.Timestamp(\'2021/01/01 00:37\'),\r\n                           pd.Timestamp(\'2021/01/01 00:40\'),\r\n                           pd.Timestamp(\'2021/01/01 01:00\'),\r\n                           pd.Timestamp(\'2021/01/01 03:45\'),\r\n                           pd.Timestamp(\'2021/01/01 03:59\'),\r\n                           pd.Timestamp(\'2021/01/01 05:20\')])\r\nlength = len(ts_open)\r\nrandom.seed(1)\r\nvolume = random.sample(range(1, length+1), length)\r\ndf_smpl = pd.DataFrame({\'volume\' : volume, \'ts_open\': ts_open})\r\n\r\n# Left data\r\nts_full = pd.date_range(start=pd.Timestamp(\'2021/01/01 00:00\'),\r\n                        periods=7, freq=\'1h\')\r\nts_event = ts_full[:-1]\r\nlength_ipr = len(ts_event)\r\nrandom.seed(2)\r\nvolume = random.sample(range(20, length_ipr+20), length_ipr)\r\ndf_ipr = pd.DataFrame({\'volume\' : volume, \'timestamp\': ts_event})\r\n\r\nat = ts_full[1:]\r\ndf_smpl.index = df_smpl[\'ts_open\']\r\n\r\n# Test\r\ndf_full = pd.merge_asof(df_ipr, df_smpl,\r\n                        left_on=at, right_index=True,\r\n                        allow_exact_matches=False, direction=\'backward\')\r\n```\r\n\r\nError message:\r\n```python\r\nTraceback (most recent call last):\r\n\r\n  File "<ipython-input-152-b5845a330a4b>", line 30, in <module>\r\n    df_full = pd.merge_asof(df_ipr, df_smpl,\r\n\r\n  File "/home/yoh/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py", line 581, in merge_asof\r\n    op = _AsOfMerge(\r\n\r\n  File "/home/yoh/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py", line 1736, in __init__\r\n    _OrderedMerge.__init__(\r\n\r\n  File "/home/yoh/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py", line 1619, in __init__\r\n    _MergeOperation.__init__(\r\n\r\n  File "/home/yoh/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py", line 682, in __init__\r\n    self._validate_specification()\r\n\r\n  File "/home/yoh/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py", line 1782, in _validate_specification\r\n    if left_on in self.left.columns\r\n\r\n  File "/home/yoh/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 4572, in __contains__\r\n    hash(key)\r\n\r\nTypeError: unhashable type: \'DatetimeIndex\'\r\n```\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : c7f7443c1bad8262358114d5e88cd9c8a308e8aa\r\npython           : 3.8.8.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.8.0-63-generic\r\nVersion          : #71~20.04.1-Ubuntu SMP Thu Jul 15 17:46:08 UTC 2021\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.3.1\r\nnumpy            : 1.20.3\r\npytz             : 2021.1\r\ndateutil         : 2.8.2\r\npip              : 21.1.3\r\nsetuptools       : 52.0.0.post20210125\r\nCython           : 0.29.24\r\npytest           : 6.2.4\r\nhypothesis       : None\r\nsphinx           : 4.0.2\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 2.11.3\r\nIPython          : 7.22.0\r\npandas_datareader: None\r\nbs4 ...
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42843',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42843/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42843/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42843/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/42843',
#   'id': 957553904,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NzAwOTU4NDA0',
#   'number': 42843,
#   'title': 'REGR: sample modifying `weights` inplace',
#   'user': {'login': 'mzeitlin11',
#    'id': 37011898,
#    'node_id': 'MDQ6VXNlcjM3MDExODk4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37011898?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mzeitlin11',
#    'html_url': 'https://github.com/mzeitlin11',
#    'followers_url': 'https://api.github.com/users/mzeitlin11/followers',
#    'following_url': 'https://api.github.com/users/mzeitlin11/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mzeitlin11/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mzeitlin11/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mzeitlin11/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mzeitlin11/orgs',
#    'repos_url': 'https://api.github.com/users/mzeitlin11/repos',
#    'events_url': 'https://api.github.com/users/mzeitlin11/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mzeitlin11/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 57296398,
#     'node_id': 'MDU6TGFiZWw1NzI5NjM5OA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Algos',
#     'name': 'Algos',
#     'color': 'eb6420',
#     'default': False,
#     'description': 'Non-arithmetic algos: value_counts, factorize, sorting, isin, clip, shift, diff'},
#    {'id': 32815646,
#     'node_id': 'MDU6TGFiZWwzMjgxNTY0Ng==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Regression',
#     'name': 'Regression',
#     'color': 'e11d21',
#     'default': False,
#     'description': 'Functionality that used to work in a prior pandas version'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/86',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/86',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/86/labels',
#    'id': 6840253,
#    'node_id': 'MDk6TWlsZXN0b25lNjg0MDI1Mw==',
#    'number': 86,
#    'title': '1.4',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 38,
#    'closed_issues': 263,
#    'state': 'open',
#    'created_at': '2021-06-09T18:28:42Z',
#    'updated_at': '2021-08-01T18:14:16Z',
#    'due_on': '2021-12-31T08:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2021-08-01T18:13:52Z',
#   'updated_at': '2021-08-01T18:14:54Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/42843',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/42843',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/42843.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/42843.patch'},
#   'body': '- [x] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [x] whatsnew entry\r\n\r\nTargeting 1.4 and no whatsnew since only a regression on master.\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42842',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42842/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42842/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42842/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/42842',
#   'id': 957526515,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NzAwOTM2NTc4',
#   'number': 42842,
#   'title': 'CI: Upgrade codecov-action to v2',
#   'user': {'login': 'lithomas1',
#    'id': 47963215,
#    'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lithomas1',
#    'html_url': 'https://github.com/lithomas1',
#    'followers_url': 'https://api.github.com/users/lithomas1/followers',
#    'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#    'repos_url': 'https://api.github.com/users/lithomas1/repos',
#    'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Related to Continuous Integration'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/88',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/88',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/88/labels',
#    'id': 6998423,
#    'node_id': 'MI_kwDOAA0YD84AasmX',
#    'number': 88,
#    'title': '1.3.2',
#    'description': 'on-merge: backport to 1.3.x',
#    'creator': {'login': 'simonjayhawkins',
#     'id': 13159005,
#     'node_id': 'MDQ6VXNlcjEzMTU5MDA1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/13159005?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/simonjayhawkins',
#     'html_url': 'https://github.com/simonjayhawkins',
#     'followers_url': 'https://api.github.com/users/simonjayhawkins/followers',
#     'following_url': 'https://api.github.com/users/simonjayhawkins/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/simonjayhawkins/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/simonjayhawkins/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/simonjayhawkins/subscriptions',
#     'organizations_url': 'https://api.github.com/users/simonjayhawkins/orgs',
#     'repos_url': 'https://api.github.com/users/simonjayhawkins/repos',
#     'events_url': 'https://api.github.com/users/simonjayhawkins/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/simonjayhawkins/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 34,
#    'closed_issues': 33,
#    'state': 'open',
#    'created_at': '2021-07-23T08:57:52Z',
#    'updated_at': '2021-08-02T09:34:27Z',
#    'due_on': '2021-08-15T07:00:00Z',
#    'closed_at': None},
#   'comments': 1,
#   'created_at': '2021-08-01T16:02:04Z',
#   'updated_at': '2021-08-02T03:41:40Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/42842',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/42842',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/42842.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/42842.patch'},
#   'body': '- [ ] closes #xxxx\r\n- [ ] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [ ] whatsnew entry\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42841',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42841/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42841/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42841/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/42841',
#   'id': 957518944,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NzAwOTMwNjQ0',
#   'number': 42841,
#   'title': 'PERF: GroupBy.any/all operate blockwise instead of column-wise',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 57296398,
#     'node_id': 'MDU6TGFiZWw1NzI5NjM5OA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Algos',
#     'name': 'Algos',
#     'color': 'eb6420',
#     'default': False,
#     'description': 'Non-arithmetic algos: value_counts, factorize, sorting, isin, clip, shift, diff'},
#    {'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None},
#    {'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-08-01T15:24:08Z',
#   'updated_at': '2021-08-02T03:44:13Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/42841',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/42841',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/42841.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/42841.patch'},
#   'body': "- [ ] closes #xxxx\r\n- [ ] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [ ] whatsnew entry\r\n\r\nThe idea is to incrementally move all of the relevant functions to operate block-wise, at which point we can also de-duplicate _get_cythonized_result with _cython_agg_general.\r\n\r\nFleshes out the asv, which currently checks only single-column, to measure ncols=1, 2, 5, 10.  We take a performance hit on the ncols==1 case and improve all the others (ex some noise)\r\n\r\n```\r\nasv continuous -f 1.01 master HEAD -E virtualenv -b GroupByMethods --append-samples --record-samples\r\n[...]\r\n       before           after         ratio\r\n     [a5f8c9a0]       [8586317b]\r\n     <perf-from_records>       <perf-gb> \r\n+        58.2±5μs        71.7±20μs     1.23  groupby.GroupByMethods.time_dtype_as_field('int', 'all', 'transformation', 1)\r\n+        76.9±6μs        94.1±20μs     1.22  groupby.GroupByMethods.time_dtype_as_field('int', 'all', 'direct', 10)\r\n+        66.7±3μs        81.2±20μs     1.22  groupby.GroupByMethods.time_dtype_as_field('int', 'any', 'transformation', 2)\r\n+        65.9±3μs        78.4±20μs     1.19  groupby.GroupByMethods.time_dtype_as_field('int', 'any', 'direct', 2)\r\n+        68.9±2μs        81.8±20μs     1.19  groupby.GroupByMethods.time_dtype_as_field('int', 'all', 'direct', 5)\r\n+        77.0±4μs        91.3±30μs     1.19  groupby.GroupByMethods.time_dtype_as_field('int', 'all', 'transformation', 10)\r\n+        177±10μs         210±40μs     1.18  groupby.GroupByMethods.time_dtype_as_field('int', 'cumcount', 'transformation', 5)\r\n+        66.1±2μs        77.3±20μs     1.17  groupby.GroupByMethods.time_dtype_as_field('int', 'all', 'direct', 2)\r\n+      57.1±0.9μs        64.7±20μs     1.13  groupby.GroupByMethods.time_dtype_as_field('int', 'any', 'direct', 1)\r\n+       67.1±10μs        75.9±10μs     1.13  groupby.GroupByMethods.time_dtype_as_field('float', 'all', 'direct', 5)\r\n+        65.4±3μs        72.6±20μs     1.11  groupby.GroupByMethods.time_dtype_as_field('int', 'all', 'transformation', 2)\r\n+        56.7±1μs        62.8±20μs     1.11  groupby.GroupByMethods.time_dtype_as_field('int', 'all', 'direct', 1)\r\n+        77.2±2μs        85.4±20μs     1.11  groupby.GroupByMethods.time_dtype_as_field('int', 'any', 'transformation', 10)\r\n+       66.0±10μs        73.0±10μs     1.11  groupby.GroupByMethods.time_dtype_as_field('float', 'all', 'direct', 2)\r\n+        78.2±4μs        86.4±20μs     1.10  groupby.GroupByMethods.time_dtype_as_field('int', 'any', 'direct', 10)\r\n+         20.8±0s          22.7±0s     1.09  groupby.GroupByMethods.time_dtype_as_group('float', 'describe', 'direct', 10)\r\n+        69.3±2μs        75.6±20μs     1.09  groupby.GroupByMethods.time_dtype_as_field('int', 'any', 'transformation', 5)\r\n+       76.6±10μs        82.6±20μs     1.08  groupby.GroupByMethods.time_dtype_as_field('float', 'all', 'direct', 10)\r\n+        105±20μs         113±30μs     1.08  groupby.GroupByMethods.time_dtype_as_field('float', 'max', 'direct', 5)\r\n+         13.4±0s          14.3±0s     1.07  groupby.GroupByMethods.time_dtype_as_group('int', 'describe', 'direct', 10)\r\n+        59.4±3μs        63.4±20μs     1.07  groupby.GroupByMethods.time_dtype_as_field('int', 'any', 'transformation', 1)\r\n+        70.2±2μs        74.6±20μs     1.06  groupby.GroupByMethods.time_dtype_as_field('int', 'all', 'transformation', 5)\r\n+         20.9±0s          22.1±0s     1.06  groupby.GroupByMethods.time_dtype_as_group('float', 'describe', 'transformation', 10)\r\n+         13.5±0s          14.1±0s     1.05  groupby.GroupByMethods.time_dtype_as_group('int', 'describe', 'transformation', 10)\r\n+         13.2±0s        13.5±0.2s     1.03  groupby.GroupByMethods.time_dtype_as_group('uint', 'describe', 'direct', 10)\r\n+         13.2±0s       13.4±0.06s   ...
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42840',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42840/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42840/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42840/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/42840',
#   'id': 957509023,
#   'node_id': 'MDU6SXNzdWU5NTc1MDkwMjM=',
#   'number': 42840,
#   'title': 'BUG: Concat does not preserve category if lists of categories do not match.',
#   'user': {'login': 'yohplala',
#    'id': 13206058,
#    'node_id': 'MDQ6VXNlcjEzMjA2MDU4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13206058?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yohplala',
#    'html_url': 'https://github.com/yohplala',
#    'followers_url': 'https://api.github.com/users/yohplala/followers',
#    'following_url': 'https://api.github.com/users/yohplala/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/yohplala/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/yohplala/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/yohplala/subscriptions',
# ...
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42813',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42813/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42813/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42813/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/42813',
#   'id': 956537413,
#   'node_id': 'MDU6SXNzdWU5NTY1Mzc0MTM=',
#   'number': 42813,
#   'title': 'rollback and rollforward both of them  gives  same response for month end business day',
#   'user': {'login': 'crazysa',
#    'id': 32246311,
#    'node_id': 'MDQ6VXNlcjMyMjQ2MzEx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32246311?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/crazysa',
#    'html_url': 'https://github.com/crazysa',
#    'followers_url': 'https://api.github.com/users/crazysa/followers',
#    'following_url': 'https://api.github.com/users/crazysa/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/crazysa/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/crazysa/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/crazysa/subscriptions',
#    'organizations_url': 'https://api.github.com/users/crazysa/orgs',
#    'repos_url': 'https://api.github.com/users/crazysa/repos',
#    'events_url': 'https://api.github.com/users/crazysa/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/crazysa/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 53181044,
#     'node_id': 'MDU6TGFiZWw1MzE4MTA0NA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Frequency',
#     'name': 'Frequency',
#     'color': '0052cc',
#     'default': False,
#     'description': 'DateOffsets'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2021-07-30T08:41:45Z',
#   'updated_at': '2021-07-30T11:46:49Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "When the date we pass is  the last business day of the month  in rollback and rollforward both of them returns the  same date we passed , shouldn't it give the previous month last business day for rollback and the passed date for rollforward . \r\n\r\neg.:  30th july 2021 ",
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42810',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42810/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42810/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42810/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/42810',
#   'id': 956430146,
#   'node_id': 'MDU6SXNzdWU5NTY0MzAxNDY=',
#   'number': 42810,
#   'title': 'BUG: DataFrame constructor fails to repeat length-1 list to length of index if it contains a Timestamp/datetime64',
#   'user': {'login': 'RobbieClarken',
#    'id': 663161,
#    'node_id': 'MDQ6VXNlcjY2MzE2MQ==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/663161?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RobbieClarken',
#    'html_url': 'https://github.com/RobbieClarken',
#    'followers_url': 'https://api.github.com/users/RobbieClarken/followers',
#    'following_url': 'https://api.github.com/users/RobbieClarken/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/RobbieClarken/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/RobbieClarken/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/RobbieClarken/subscriptions',
#    'organizations_url': 'https://api.github.com/users/RobbieClarken/orgs',
#    'repos_url': 'https://api.github.com/users/RobbieClarken/repos',
#    'events_url': 'https://api.github.com/users/RobbieClarken/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/RobbieClarken/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1465286368,
#     'node_id': 'MDU6TGFiZWwxNDY1Mjg2MzY4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Constructors',
#     'name': 'Constructors',
#     'color': 'd4c5f9',
#     'default': False,
#     'description': 'Series/DataFrame/Index/pd.array Constructors'},
#    {'id': 32815646,
#     'node_id': 'MDU6TGFiZWwzMjgxNTY0Ng==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Regression',
#     'name': 'Regression',
#     'color': 'e11d21',
#     'default': False,
#     'description': 'Functionality that used to work in a prior pandas version'},
#    {'id': 211840,
#     'node_id': 'MDU6TGFiZWwyMTE4NDA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timeseries',
#     'name': 'Timeseries',
#     'color': 'AFEEEE',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/88',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/88',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/88/labels',
#    'id': 6998423,
#    'node_id': 'MI_kwDOAA0YD84AasmX',
#    'number': 88,
#    'title': '1.3.2',
#    'description': 'on-merge: backport to 1.3.x',
#    'creator': {'login': 'simonjayhawkins',
#     'id': 13159005,
#     'node_id': 'MDQ6VXNlcjEzMTU5MDA1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/13159005?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/simonjayhawkins',
#     'html_url': 'https://github.com/simonjayhawkins',
#     'followers_url': 'https://api.github.com/users/simonjayhawkins/followers',
#     'following_url': 'https://api.github.com/users/simonjayhawkins/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/simonjayhawkins/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/simonjayhawkins/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/simonjayhawkins/subscriptions',
#     'organizations_url': 'https://api.github.com/users/simonjayhawkins/orgs',
#     'repos_url': 'https://api.github.com/users/simonjayhawkins/repos',
#     'events_url': 'https://api.github.com/users/simonjayhawkins/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/simonjayhawkins/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 34,
#    'closed_issues': 33,
#    'state': 'open',
#    'created_at': '2021-07-23T08:57:52Z',
#    'updated_at': '2021-08-02T09:34:27Z',
#    'due_on': '2021-08-15T07:00:00Z',
#    'closed_at': None},
#   'comments': 1,
#   'created_at': '2021-07-30T05:59:57Z',
#   'updated_at': '2021-07-30T11:50:41Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [x] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\nimport pandas as pd\r\npd.DataFrame([[pd.Timestamp("2021-01-01")]], index=[1, 2, 3])\r\n```\r\n\r\nThis will throw an exception:\r\n\r\n```\r\nTraceback (most recent call last):\r\n  File "/tmp/venv/lib/python3.9/site-packages/pandas/core/internals/managers.py", line 1770, in create_block_manager_from_arrays\r\n    mgr = BlockManager(blocks, axes)\r\n  File "/tmp/venv/lib/python3.9/site-packages/pandas/core/internals/managers.py", line 910, in __init__\r\n    self._verify_integrity()\r\n  File "/tmp/venv/lib/python3.9/site-packages/pandas/core/internals/managers.py", line 917, in _verify_integrity\r\n    raise construction_error(tot_items, block.shape[1:], self.axes)\r\nValueError: Shape of passed values is (1, 1), indices imply (3, 1)\r\n\r\nDuring handling of the above exception, another exception occurred:\r\n\r\nTraceback (most recent call last):\r\n  File "<stdin>", line 1, in <module>\r\n  File "/tmp/venv/lib/python3.9/site-packages/pandas/core/frame.py", line 702, in __init__\r\n    mgr = arrays_to_mgr(\r\n  File "/tmp/venv/lib/python3.9/site-packages/pandas/core/internals/construction.py", line 135, in arrays_to_mgr\r\n    return create_block_manager_from_arrays(\r\n  File "/tmp/venv/lib/python3.9/site-packages/pandas/core/internals/managers.py", line 1772, in create_block_manager_from_arrays\r\n    raise construction_error(len(arrays), arrays[0].shape, axes, e)\r\nValueError: Shape of passed values is (1, 1), indices imply (3, 1)\r\n```\r\n\r\nThe same exception will also be raised when the `data` argument is a list-of-dicts but not when `data` is a dict-of-lists:\r\n\r\n```python\r\npd.DataFrame([{"x": pd.Timestamp("2021-01-01"}], index=[1, 2, 3])  # this will fail due to the same exception\r\npd.DataFrame({"x": [pd.Timestamp("2021-01-01")]}, index=[1, 2, 3])  # this format is ok\r\n```\r\n\r\n#### Problem description\r\n\r\nFrom what I can tell, the `DataFrame` constructor supports supplying a length-1 list and an index of length greater than 1 as long as the list doesn\'t contain a value of type `Timestamp` / `datetime64`. Raising an error only for these types is therefore inconsistent and could lead to user confusion. It is also a change from the behaviour in pandas 1.2 where it was possible to supply a length-1 list containing a `Timestamp`.\r\n\r\n```\r\n>>> pd.__version__\r\n\'1.3.1\'\r\n>>> pd.DataFrame([[7]], index=[1, 2, 3])\r\n   0\r\n1  7\r\n2  7\r\n3  7\r\n>>> pd.DataFrame([["abc"]], index=[1, 2, 3])\r\n     0\r\n1  abc\r\n2  abc\r\n3  abc\r\n>>> pd.DataFrame([[object()]], index=[1, 2, 3])\r\n                                0\r\n1  <object object at 0x111a16e20>\r\n2  <object object at 0x111a16e20>\r\n3  <object object at 0x111a16e20>\r\n```\r\n\r\nIn Pandas 1.2.5:\r\n\r\n```\r\n>>> import pandas as pd\r\n>>> pd.__version__\r\n\'1.2.5\'\r\n>>> pd.DataFrame([[pd.Timestamp("2021-01-01")]], index=[1, 2, 3])\r\n           0\r\n1 2021-01-01\r\n2 2021-01-01\r\n3 2021-01-01\r\n```\r\n\r\n#### Expected Output\r\n\r\nThe length-1 list should be repeated to the length of the index:\r\n\r\n```\r\n>>> pd.DataFrame([[pd.Timestamp("2021-01-01")]], index=[1, 2, 3])\r\n           0\r\n1 2021-01-01\r\n2 2021-01-01\r\n3 2021-01-01\r\n```\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : c7f7443c1bad8262358114d5e88cd9c8a308e8aa\r\npython           : 3.9.4.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 18.7.0\r\nVersion          : Darwin Kernel Version 18.7.0: Mon May  3 20:41:19 PDT 2021; root:xnu-4903.278.68~1/RELEASE_X86_64\r\nmachine          : x86_64\r\nprocessor        : i386\r\nby ...
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42809',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42809/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42809/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42809/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/42809',
#   'id': 956290908,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0Njk5OTEyNjky',
#   'number': 42809,
#   'title': 'DOC: Fixed GL02 errors in documentation',
#   'user': {'login': 'fshi01',
#    'id': 74736949,
#    'node_id': 'MDQ6VXNlcjc0NzM2OTQ5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/74736949?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fshi01',
#    'html_url': 'https://github.com/fshi01',
#    'followers_url': 'https://api.github.com/users/fshi01/followers',
#    'following_url': 'https://api.github.com/users/fshi01/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/fshi01/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/fshi01/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/fshi01/subscriptions',
#    'organizations_url': 'https://api.github.com/users/fshi01/orgs',
#    'repos_url': 'https://api.github.com/users/fshi01/repos',
#    'events_url': 'https://api.github.com/users/fshi01/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/fshi01/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/86',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/86',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/86/labels',
#    'id': 6840253,
#    'node_id': 'MDk6TWlsZXN0b25lNjg0MDI1Mw==',
#    'number': 86,
#    'title': '1.4',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 38,
#    'closed_issues': 263,
#    'state': 'open',
#    'created_at': '2021-06-09T18:28:42Z',
#    'updated_at': '2021-08-01T18:14:16Z',
#    'due_on': '2021-12-31T08:00:00Z',
#    'closed_at': None},
#   'comments': 2,
#   'created_at': '2021-07-30T00:06:20Z',
#   'updated_at': '2021-07-31T01:40:47Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/42809',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/42809',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/42809.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/42809.patch'},
#   'body': 'Fixed 2 of the 4 GL02 errors generated by pandas_validation_errors.ipynb \r\nThe remaining two errors are from pandas.Timestamp.isoweekday and will be tackled next. \r\n',
#   'performed_via_github_app': None}]

# %%
issues = pd.DataFrame(data, columns=['number', 'title',
                                     'labels', 'state'])
issues

# %% [markdown]
# ## Interacting with Databases

# %%
import sqlite3
query = """
CREATE TABLE test
(a VARCHAR(20), b VARCHAR(20),
 c REAL,        d INTEGER
);"""
con = sqlite3.connect('mydata.sqlite')
con.execute(query)
con.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-9-7d31cf7a3bea> in <module>
#       6 );"""
#       7 con = sqlite3.connect('mydata.sqlite')
# ----> 8 con.execute(query)
#       9 con.commit()
#
# OperationalError: table test already exists

# %%
data = [('Atlanta', 'Georgia', 1.25, 6),
        ('Tallahassee', 'Florida', 2.6, 3),
        ('Sacramento', 'California', 1.7, 5)]
stmt = "INSERT INTO test VALUES(?, ?, ?, ?)"
con.executemany(stmt, data)
con.commit()

# %%
cursor = con.execute('select * from test')
rows = cursor.fetchall()
rows
# Out:
# [('Atlanta', 'Georgia', 1.25, 6),
#  ('Tallahassee', 'Florida', 2.6, 3),
#  ('Sacramento', 'California', 1.7, 5)]

# %%
cursor.description
pd.DataFrame(rows, columns=[x[0] for x in cursor.description])

# %%
import sqlalchemy as sqla
db = sqla.create_engine('sqlite:///mydata.sqlite')
pd.read_sql('select * from test', db)

# %%
# !rm mydata.sqlite

# %% [markdown]
# ## Conclusion
